# %%
import pandas as pd
import numpy as np
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from geopy.distance import great_circle
from shapely.geometry import MultiPoint
from collections import defaultdict

# %%
pg = pd.read_csv('/Users/krishnamchapa/BITS/Sem3/DataScience/PredictiveAnalysisOfSingaporeRentalPrices/apartment_rental_prices.csv')

# %%
print(pg.shape)
# Out:
# (805, 21)

# %%
pg['Price'].idxmax()
# Out:
# 421

# %%
pg.sort_values(by='Price', ascending=True).head()
# Out:
#                                                    url  \
# 273  https://www.propertyguru.com.sg/listing/229247...
# 539  https://www.propertyguru.com.sg/listing/223828...
# 791  https://www.propertyguru.com.sg/listing/229286...
# 690  https://www.propertyguru.com.sg/listing/229313...
# 32   https://www.propertyguru.com.sg/listing/226143...
#
#                                                  Image  \
# 273  https://sg2-cdn.pgimgs.com/listing/22924770/UP...
# 539  https://sg1-cdn.pgimgs.com/listing/22382893/UP...
# 791  https://sg1-cdn.pgimgs.com/listing/22928617/UP...
# 690  https://sg1-cdn.pgimgs.com/listing/22931326/UP...
# 32   https://sg1-cdn.pgimgs.com/listing/22614305/UP...
#
#                                              Image_alt            Name  \
# 273  The Minton #121027183; The Minton #121027160; ...      The Minton
# 539  Gem Residences #120692608; Gem Residences #120...  Gem Residences
# 791  Casa Cambio #121067210; Casa Cambio #121067268...     Casa Cambio
# 690  Sims Edge #121095794; Sims Edge #121095801; Si...       Sims Edge
# 32   Auralis #117879792; Auralis #117879795; Aurali...         Auralis
#
#                                            Description  Price Price Currency  \
# 273  Description\n \nCheapest Studio Unit for Rent\...   2000            SGD
# 539  Description\n \nUnblock view\n Dual key unit \...   2000            SGD
# 791  Description\n \nCall now to enquire\n New Excl...   2000            SGD
# 690  Description\n \nHigh floor 1 bedroom for rent\...   2000            SGD
# 32   Description\n \nNear Future Marine Terrace MRT...   2000            SGD
#
#                                    Additional Property  \
# 273  Type; Tenure; Floor size; Developer; Land size...
# 539  Type; Tenure; Floor size; Developer; Land size...
# 791  Type; Tenure; Floor size; Developer; Land size...
# 690  Type; Tenure; Floor size; Developer; Land size...
# 32   Type; Tenure; Floor size; Developer; Land size...
#
#                                Additional Property (2)  \
# 273  Condominium For Rent; 99-year Leasehold; 500 s...
# 539  Condominium For Rent; 99-year Leasehold; 325 s...
# 791  Condominium For Rent; Freehold; 581 sqft; Urba...
# 690  Condominium For Rent; Freehold; 409 sqft; MACL...
# 32   Condominium For Rent; Freehold; 463 sqft; Sino...
#
#                                        Amenity Feature  ... Country  \
# 273  Air-Conditioning; Bed; Cable TV; Cooker Hob/Ho...  ...      sg
# 539  Air-Conditioning; Balcony; Cooker Hob/Hood; Co...  ...      sg
# 791  Air-Conditioning; Balcony; Bombshelter; Cooker...  ...      sg
# 690  Air-Conditioning; Balcony; Bed; Cooker Hob/Hoo...  ...      sg
# 32   Barbeque Area; Fitness corner; Pavillion; Pool...  ...      sg
#
#     Floor Size  Floor Size Unit Text Geo Latitude  Geo Longitude  \
# 273        500                  sqft     1.351835     103.881365
# 539        325                  sqft     1.333689     103.853167
# 791        581                  sqft     1.353758     103.876408
# 690        409                  sqft     1.316387     103.887910
# 32         463                  sqft     1.310159     103.916081
#
#                          Locality Number Of Rooms  Postal Code  \
# 273  Hougang / Punggol / Sengkang               1     530147.0
# 539         Balestier / Toa Payoh               1     319999.0
# 791  Hougang / Punggol / Sengkang               1     547726.0
# 690  Eunos / Geylang / Paya Lebar               1     389760.0
# 32     East Coast / Marine Parade               1     429081.0
#
#                     Street Address  \
# 273          147 Hougang Street 11
# 539  Lorong 4 / Lorong 6 Toa Payoh
# 791             9 Lim Tua Tow Road
# 690        1 Geylang East Avenue 2
# 32             589 East Coast Road
#
#                                             _url_input
# 273  https://www.propertyguru.com.sg/listing/229247...
# 539  https://www.propertyguru.com.sg/listing/223828...
# 791  https://www.propertyguru.com.sg/listing/229286...
# 690  https://www.propertyguru.com.sg/listing/229313...
# 32   https://www.propertyguru.com.sg/listing/226143...
#
# [5 rows x 21 columns]

# %%
pg['Price'].mean()
# Out:
# 2935.2683229813665

# %%
pg['Size in sqm'] = pg['Floor Size'].apply(lambda x: round(x * 0.092903, 1))

# %%
pg.head()
# Out:
#                                                  url  \
# 0  https://www.propertyguru.com.sg/listing/223600...
# 1  https://www.propertyguru.com.sg/listing/223781...
# 2  https://www.propertyguru.com.sg/listing/219227...
# 3  https://www.propertyguru.com.sg/listing/228745...
# 4  https://www.propertyguru.com.sg/listing/223646...
#
#                                                Image  \
# 0  https://sg1-cdn.pgimgs.com/listing/22360097/UP...
# 1  https://sg1-cdn.pgimgs.com/listing/22378100/UP...
# 2  https://sg1-cdn.pgimgs.com/listing/21922747/UP...
# 3  https://sg2-cdn.pgimgs.com/listing/22874585/UP...
# 4  https://sg1-cdn.pgimgs.com/listing/22364662/UP...
#
#                                            Image_alt                   Name  \
# 0  Park Place Residences #116641240; Park Place R...  Park Place Residences
# 1  Park Place Residences #118873192; Park Place R...  Park Place Residences
# 2  Sturdee Residences #119960144; Sturdee Residen...     Sturdee Residences
# 3  105 LOR G TELOK KURAU #120806907; 105 LOR G TE...  105 LOR G TELOK KURAU
# 4  Park Place Residences #115222062; Park Place R...  Park Place Residences
#
#                                          Description  Price Price Currency  \
# 0  Description\n \nVery high floor Unblock view. ...   2600            SGD
# 1  Description\n \nMultiple units on hand, differ...   2700            SGD
# 2  Description\n \nKeys on hand! Many units avail...   2500            SGD
# 3  Description\n \nSpacious, Well maintained, 1 b...   2500            SGD
# 4  Description\n \nLuxury Brand New! Walk to Paya...   2499            SGD
#
#                                  Additional Property  \
# 0  Type; Tenure; Floor size; Developer; Land size...
# 1  Type; Tenure; Floor size; Developer; Land size...
# 2  Type; Tenure; Floor size; Developer; Land size...
# 3  Type; Tenure; Floor size; Developer; Land size...
# 4  Type; Tenure; Floor size; Developer; Land size...
#
#                              Additional Property (2)  \
# 0  Condominium For Rent; 99-year Leasehold; 484 s...
# 1  Condominium For Rent; 99-year Leasehold; 484 s...
# 2  Condominium For Rent; 99-year Leasehold; 420 s...
# 3  Condominium For Rent; N/A; 650 sqft; N/A; N/A;...
# 4  Condominium For Rent; 99-year Leasehold; 484 s...
#
#                                      Amenity Feature  ... Floor Size  \
# 0  Air-Conditioning; Balcony; City View; Cooker H...  ...        484
# 1  Air-Conditioning; Balcony; City View; Cooker H...  ...        484
# 2  Air-Conditioning; Balcony; City View; Cooker H...  ...        420
# 3  Air-Conditioning; Balcony; Corner Unit; Dryer;...  ...        650
# 4  Air-Conditioning; Balcony; Bed; Cooker Hob/Hoo...  ...        484
#
#   Floor Size Unit Text  Geo Latitude Geo Longitude  \
# 0                 sqft      1.316608    103.892443
# 1                 sqft      1.316608    103.892443
# 2                 sqft      1.312388    103.859168
# 3                 sqft      1.318228    103.913134
# 4                 sqft      1.316608    103.892443
#
#                        Locality  Number Of Rooms Postal Code  \
# 0  Eunos / Geylang / Paya Lebar                1    409055.0
# 1  Eunos / Geylang / Paya Lebar                1    409055.0
# 2    Farrer Park / Serangoon Rd                1    209999.0
# 3  Eunos / Geylang / Paya Lebar                1    426305.0
# 4  Eunos / Geylang / Paya Lebar                1    409055.0
#
#       Street Address                                         _url_input  \
# 0  6 Paya Lebar Road  https://www.propertyguru.com.sg/listing/223600...
# 1  6 Paya Lebar Road  https://www.propertyguru.com.sg/listing/223781...
# 2       Sturdee Road  https://www.propertyguru.com.sg/listing/219227...
# 3  LOR G TELOK KURAU  https://www.propertyguru.com.sg/listing/228745...
# 4  6 Paya Lebar Road  https://www.propertyguru.com.sg/listing/223646...
#
#   Size in sqm
# 0        45.0
# 1        45.0
# 2        39.0
# 3        60.4
# 4        45.0
#
# [5 rows x 22 columns]

# %%
appCoords = pg[['Geo Latitude', 'Geo Longitude']].to_numpy()

# %%
kms_per_radian = 6371.0088
epsilon = 0.5 / kms_per_radian
db = DBSCAN(eps=epsilon, min_samples=1, algorithm='ball_tree', metric='haversine').fit(np.radians(appCoords))
cluster_labels = db.labels_
num_clusters = len(set(cluster_labels))
clusters = pd.Series([appCoords[cluster_labels == n] for n in range(num_clusters)])
clusters
# Out:
# 0     [[1.316608, 103.892443], [1.316608, 103.892443...
# 1     [[1.3123877, 103.85916800000001], [1.3123877, ...
# 2                              [[1.318228, 103.913134]]
# 3     [[1.3314177332728, 103.86714582209], [1.330599...
# 4                                 [[1.3163, 103.94044]]
#                             ...
# 73                           [[1.3062299, 103.8882208]]
# 74                     [[1.280985, 103.84078120000001]]
# 75                 [[1.3791766507808, 103.90283554257]]
# 76           [[1.3269841999999998, 103.82299429999999]]
# 77                            [[1.2718989, 103.827198]]
# Length: 78, dtype: object

# %%
clustersWithProperties = {}
for i, cluster in clusters.items():
    for propertyCoords in cluster:
        singleResidence = pg[(pg['Geo Latitude'] == propertyCoords[0]) & (pg['Geo Longitude'] == propertyCoords[1])]
        for j, unit in singleResidence.iterrows():
            residenceNameCleansed = ''.join(e for e in unit['Name'] if e.isalnum() and not e.isdigit())
            if i in clustersWithProperties:
                if residenceNameCleansed in clustersWithProperties.get(i):
                    clustersWithProperties[i][residenceNameCleansed].append(unit['Price'])
                else:
                    clustersWithProperties[i][residenceNameCleansed] = [unit['Price']]
            else:
                clustersWithProperties[i] = {residenceNameCleansed: [unit['Price']]}

# %%
averagePricePerCluster = []
for i, cluster in clustersWithProperties.items():
    numberOfUnits = 0
    totalRentalPricePerCluster = 0
    for propertyName, prices in cluster.items():
        totalRentalPricePerCluster += sum(prices) 
        numberOfUnits += len(prices)
    averagePricePerCluster.append([i, round(totalRentalPricePerCluster / numberOfUnits)])

# %%
dfAveragePrice = pd.DataFrame(averagePricePerCluster, columns=['Cluster No', 'Average Price'])

# %%
path='/Users/krishnamchapa/BITS/Sem3/DataScience/PredictiveAnalysisOfSingaporeRentalPrices/average_apartment_rental_price.csv'
dfAveragePrice.to_csv(path)

# %%
def get_centermost_point(cluster):
    centroid = (MultiPoint(cluster).centroid.x, MultiPoint(cluster).centroid.y)
    centermost_point = min(cluster, key=lambda point: great_circle(point, centroid).m)
    return centermost_point
centermost_points = clusters.map(get_centermost_point)
dfCentermostPoints = pd.DataFrame(centermost_points.array, columns=['Latitude', 'Longitude'])

# %%
path='/Users/krishnamchapa/BITS/Sem3/DataScience/PredictiveAnalysisOfSingaporeRentalPrices/property_clusters_coordinates.csv'
dfCentermostPoints.to_csv(path)

# %%
fig, ax = plt.subplots(figsize=[10, 6])
pg_scatter = ax.scatter(pg['Geo Latitude'], pg['Geo Longitude'], c='k', alpha=0.9, s=3)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.legend([pg_scatter], ['Property Guru Set'], loc='upper right')
plt.show()
